# %%
g = open('reviews.txt','r')
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

# %%
print(reviews)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
g = open('labels.txt','r')
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

# %%
len(reviews)
len(labels)
# Out:
# 25000

# %%
pretty_print_review_and_label(12816)
# Out:
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...

# %%
from collections import Counter
import numpy as np

# %%
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %%
for i in range(len(reviews)):
  if(labels[i] == 'POSITIVE'):
    for word in reviews[i].split(" "):
      positive_counts[word] += 1
      total_counts[word] += 1
  else:
      for word in reviews[i].split(" "):
          negative_counts[word] += 1
          total_counts[word] += 1

# %%
positive_counts.most_common()
# Out:
# [('', 343631),
#  ('the', 108337),
#  ('.', 98691),
#  ('and', 56141),
#  ('a', 51931),
#  ('of', 48292),
#  ('to', 41729),
#  ('is', 35686),
#  ('in', 31578),
#  ('br', 30621),
#  ('it', 29707),
#  ('i', 24938),
#  ('that', 22329),
#  ('this', 21754),
#  ('s', 21022),
#  ('as', 16479),
#  ('with', 14606),
#  ('for', 14108),
#  ('was', 13573),
#  ('film', 12987),
#  ('but', 12829),
#  ('movie', 11495),
#  ('his', 10675),
#  ('on', 10559),
#  ('he', 10158),
#  ('you', 10065),
#  ('are', 9205),
#  ('not', 8853),
#  ('one', 8547),
#  ('t', 8518),
#  ('have', 7883),
#  ('be', 7764),
#  ('by', 7583),
#  ('all', 7446),
#  ('who', 7258),
#  ('her', 7200),
#  ('an', 6987),
#  ('at', 6962),
#  ('from', 6779),
#  ('they', 6179),
#  ('has', 5776),
#  ('so', 5646),
#  ('like', 5529),
#  ('she', 5362),
#  ('about', 5198),
#  ('very', 5193),
#  ('out', 5022),
#  ('there', 5019),
#  ('what', 4752),
#  ('or', 4703),
#  ('more', 4702),
#  ('good', 4692),
#  ('some', 4650),
#  ('when', 4635),
#  ('if', 4499),
#  ('just', 4439),
#  ('story', 4345),
#  ('can', 4314),
#  ('time', 4047),
#  ('well', 4013),
#  ('great', 3993),
#  ('up', 3912),
#  ('my', 3895),
#  ('which', 3888),
#  ('their', 3834),
#  ('see', 3747),
#  ('also', 3449),
#  ('we', 3404),
#  ('would', 3375),
#  ('really', 3318),
#  ('had', 3263),
#  ('me', 3195),
#  ('only', 3171),
#  ('will', 3125),
#  ('him', 3123),
#  ('other', 3051),
#  ('even', 3049),
#  ('most', 3011),
#  ('first', 2996),
#  ('were', 2965),
#  ('than', 2948),
#  ('much', 2917),
#  ('its', 2862),
#  ('no', 2859),
#  ('into', 2801),
#  ('people', 2787),
#  ('love', 2779),
#  ('best', 2743),
#  ('get', 2659),
#  ('been', 2649),
#  ('how', 2595),
#  ('life', 2587),
#  ('because', 2565),
#  ('way', 2490),
#  ('do', 2424),
#  ('two', 2422),
#  ('films', 2388),
#  ('made', 2377),
#  ('many', 2358),
#  ('after', 2337),
#  ('show', 2331),
#  ('them', 2319),
#  ('too', 2300),
#  ('think', 2195),
#  ('movies', 2190),
#  ('characters', 2178),
#  ('character', 2171),
#  ('man', 2152),
#  ('don', 2107),
#  ('watch', 2098),
#  ('seen', 2091),
#  ('still', 2089),
#  ('being', 2067),
#  ('never', 2056),
#  ('make', 2029),
#  ('little', 2023),
#  ('then', 2010),
#  ('could', 1994),
#  ('where', 1925),
#  ('does', 1883),
#  ('over', 1865),
#  ('any', 1842),
#  ('while', 1795),
#  ('know', 1771),
#  ('years', 1770),
#  ('did', 1767),
#  ('here', 1727),
#  ('ever', 1724),
#  ('these', 1683),
#  ('end', 1620),
#  ('back', 1607),
#  ('such', 1604),
#  ('scene', 1603),
#  ('real', 1588),
#  ('those', 1557),
#  ('acting', 1543),
#  ('new', 1524),
#  ('off', 1516),
#  ('makes', 1516),
#  ('though', 1513),
#  ('go', 1511),
#  ('young', 1509),
#  ('through', 1508),
#  ('scenes', 1500),
#  ('work', 1483),
#  ('old', 1476),
#  ('say', 1475),
#  ('your', 1456),
#  ('both', 1452),
#  ('better', 1442),
#  ('world', 1441),
#  ('plot', 1437),
#  ('now', 1432),
#  ('find', 1418),
#  ('ve', 1408),
#  ('cast', 1375),
#  ('before', 1372),
#  ('should', 1361),
#  ('again', 1361),
#  ('something', 1350),
#  ('always', 1330),
#  ('us', 1320),
#  ('quite', 1314),
#  ('part', 1312),
#  ('actors', 1308),
#  ('director', 1286),
#  ('lot', 1281),
#  ('may', 1280),
#  ('another', 1277),
#  ('family', 1274),
#  ('series', 1274),
#  ('funny', 1248),
#  ('own', 1247),
#  ('few', 1246),
#  ('m', 1240),
#  ('role', 1227),
#  ('doesn', 1222),
#  ('between', 1212),
#  ('same', 1208),
#  ('watching', 1197),
#  ('performance', 1181),
#  ('look', 1180),
#  ('every', 1167),
#  ('why', 1166),
#  ('times', 1157),
#  ('bad', 1146),
#  ('action', 1146),
#  ('down', 1140),
#  ('re', 1132),
#  ('big', 1121),
#  ('however', 1116),
#  ('things', 1111),
#  ('actually', 1094),
#  ('going', 1089),
#  ('comedy', 1086),
#  ('long', 1086),
#  ('fact', 1082),
#  ('must', 1080),
#  ('saw', 1075),
#  ('excellent', 1071),
#  ('bit', 1062),
#  ('didn', 1062),
#  ('each', 1061),
#  ('without', 1055),
#  ('take', 1052),
#  ('beautiful', 1047),
#  ('right', 1037),
#  ('day', 1030),
#  ('around', 1023),
#  ('got', 1020),
#  ('seems', 1012),
#  ('thing', 1011),
#  ('horror', 1009),
#  ('thought', 1007),
#  ('woman', 1002),
#  ('feel', 1000),
#  ('music', 997),
#  ('done', 996),
#  ('give', 994),
#  ('fun', 988),
#  ('true', 985),
#  ('want', 985),
#  ('played', 966),
#  ('come', 966),
#  ('yet', 964),
#  ('especially', 961),
#  ('almost', 959),
#  ('last', 955),
#  ('tv', 942),
#  ('since', 935),
#  ('shows', 928),
#  ('gets', 926),
#  ('enough', 917),
#  ('job', 913),
#  ('our', 913),
#  ('interesting', 912),
#  ('different', 910),
#  ('although', 908),
#  ('pretty', 898),
#  ('original', 874),
#  ('wonderful', 872),
#  ('rather', 869),
#  ('place', 856),
#  ('probably', 849),
#  ('course', 848),
#  ('later', 847),
#  ('point', 846),
#  ('d', 840),
#  ('far', 836),
#  ('john', 836),
#  ('girl', 836),
#  ('plays', 832),
#  ('house', 824),
#  ('american', 823),
#  ('ll', 820),
#  ('dvd', 820),
#  ('once', 818),
#  ('year', 817),
#  ('together', 816),
#  ('set', 811),
#  ('away', 810),
#  ('hard', 809),
#  ('might', 807),
#  ('anyone', 806),
#  ('making', 802),
#  ('performances', 802),
#  ('having', 800),
#  ('father', 800),
#  ('whole', 799),
#  ('screen', 799),
#  ('found', 796),
#  ('comes', 796),
#  ('am', 795),
#  ('himself', 794),
#  ('takes', 793),
#  ('war', 786),
#  ('nothing', 783),
#  ('wife', 774),
#  ('isn', 765),
#  ('perfect', 762),
#  ('everyone', 761),
#  ('kind', 759),
#  ('sure', 751),
#  ('three', 747),
#  ('ending', 747),
#  ('play', 744),
#  ('worth', 739),
#  ('actor', 737),
#  ('classic', 736),
#  ('during', 724),
#  ('version', 722),
#  ('hollywood', 715),
#  ('night', 706),
#  ('goes', 705),
#  ('enjoy', 703),
#  ('everything', 695),
#  ('watched', 695),
#  ('least', 690),
#  ('anything', 686),
#  ('book', 682),
#  ('seeing', 679),
#  ('star', 678),
#  ('top', 676),
#  ('believe', 674),
#  ('men', 674),
#  ('guy', 673),
#  ('loved', 671),
#  ('put', 671),
#  ('episode', 659),
#  ('nice', 659),
#  ('truly', 656),
#  ('audience', 655),
#  ('help', 652),
#  ('seem', 650),
#  ('gives', 646),
#  ('death', 646),
#  ('looking', 645),
#  ('human', 644),
#  ('special', 639),
#  ('mother', 637),
#  ('home', 633),
#  ('sense', 633),
#  ('second', 630),
#  ('along', 627),
#  ('left', 626),
#  ('definitely', 622),
#  ('main', 621),
#  ('script', 620),
#  ('recommend', 618),
#  ('said', 618),
#  ('amazing', 618),
#  ('full', 616),
#  ('short', 609),
#  ('fan', 608),
#  ('often', 607),
#  ('trying', 606),
#  ('high', 605),
#  ('early', 601),
#  ('small', 601),
#  ('lives', 600),
#  ('mind', 595),
#  ('today', 594),
#  ('remember', 594),
#  ('black', 592),
#  ('until', 589),
#  ('others', 589),
#  ('less', 586),
#  ('won', 586),
#  ('brilliant', 584),
#  ('favorite', 583),
#  ('let', 580),
#  ('used', 579),
#  ('heart', 579),
#  ('friends', 577),
#  ('cinema', 574),
#  ('women', 570),
#  ('looks', 568),
#  ('moments', 567),
#  ('maybe', 566),
#  ('history', 566),
#  ('become', 565),
#  ('live', 564),
#  ('shot', 564),
#  ('stars', 563),
#  ('works', 563),
#  ('came', 562),
#  ('highly', 561),
#  ('picture', 555),
#  ('next', 554),
#  ('perhaps', 552),
#  ('drama', 551),
#  ('style', 551),
#  ('given', 548),
#  ('playing', 542),
#  ('boy', 541),
#  ('fine', 541),
#  ('read', 536),
#  ('liked', 534),
#  ('use', 533),
#  ('effects', 531),
#  ('someone', 529),
#  ('enjoyed', 528),
#  ('against', 524),
#  ('wasn', 523),
#  ('simply', 518),
#  ('finally', 516),
#  ('need', 516),
#  ('else', 515),
#  ('entertaining', 514),
#  ('friend', 512),
#  ('understand', 512),
#  ('minutes', 509),
#  ('reason', 509),
#  ('certainly', 508),
#  ('production', 507),
#  ('based', 506),
#  ('face', 505),
#  ('dark', 505),
#  ('strong', 501),
#  ('late', 497),
#  ('mr', 495),
#  ('couple', 494),
#  ('line', 492),
#  ('overall', 491),
#  ('throughout', 491),
#  ('person', 490),
#  ('several', 489),
#  ('rest', 489),
#  ('keep', 488),
#  ('city', 488),
#  ('child', 488),
#  ('case', 487),
#  ('art', 485),
#  ('fans', 484),
#  ('genre', 483),
#  ('beginning', 483),
#  ('written', 482),
#  ('hope', 481),
#  ('tell', 480),
#  ('soon', 477),
#  ('past', 476),
#  ('stories', 471),
#  ('start', 471),
#  ('son', 471),
#  ('children', 469),
#  ('camera', 468),
#  ('becomes', 464),
#  ('yes', 463),
#  ('itself', 462),
#  ('try', 462),
#  ('humor', 459),
#  ('under', 458),
#  ('sometimes', 457),
#  ('money', 456),
#  ('jack', 456),
#  ('able', 454),
#  ('felt', 453),
#  ('viewer', 453),
#  ('side', 449),
#  ('instead', 446),
#  ('idea', 445),
#  ('days', 444),
#  ('oscar', 443),
#  ('final', 443),
#  ('close', 442),
#  ('getting', 442),
#  ('either', 441),
#  ('name', 440),
#  ('lost', 439),
#  ('kids', 439),
#  ('sex', 438),
#  ('fantastic', 437),
#  ('despite', 437),
#  ('episodes', 437),
#  ('completely', 435),
#  ('age', 434),
#  ('roles', 434),
#  ('half', 432),
#  ('husband', 432),
#  ('wants', 431),
#  ('evil', 430),
#  ('game', 430),
#  ('directed', 429),
#  ('direction', 427),
#  ('doing', 425),
#  ('turns', 422),
#  ('white', 422),
#  ('simple', 421),
#  ('town', 420),
#  ('musical', 419),
#  ('james', 417),
#  ('murder', 416),
#  ('daughter', 416),
#  ('actress', 415),
#  ('dead', 414),
#  ('video', 413),
#  ('relationship', 413),
#  ('known', 412),
#  ('behind', 412),
#  ('title', 411),
#  ('called', 410),
#  ('absolutely', 409),
#  ('piece', 408),
#  ('sort', 408),
#  ('wrong', 408),
#  ('turn', 408),
#  ('king', 407),
#  ('experience', 406),
#  ('went', 404),
#  ('reality', 403),
#  ('budget', 403),
#  ('school', 402),
#  ('already', 402),
#  ('including', 398),
#  ('lines', 396),
#  ('themselves', 395),
#  ('chance', 394),
#  ('told', 394),
#  ('example', 393),
#  ('romantic', 393),
#  ('english', 392),
#  ('british', 392),
#  ('laugh', 392),
#  ('david', 387),
#  ('eyes', 387),
#  ('lead', 386),
#  ('parts', 386),
#  ('supporting', 386),
#  ('police', 386),
#  ('moment', 381),
#  ('season', 381),
#  ('fight', 380),
#  ('view', 380),
#  ('type', 380),
#  ('entire', 379),
#  ('documentary', 379),
#  ('living', 379),
#  ('paul', 379),
#  ('ago', 377),
#  ('released', 377),
#  ('score', 377),
#  ('care', 375),
#  ('light', 374),
#  ('finds', 373),
#  ('dialogue', 373),
#  ('hilarious', 373),
#  ('low', 371),
#  ('feeling', 371),
#  ('moving', 371),
#  ('happy', 371),
#  ('matter', 368),
#  ('quality', 366),
#  ('somewhat', 366),
#  ('coming', 366),
#  ('cinematography', 366),
#  ('shown', 366),
#  ('gave', 365),
#  ('whose', 365),
#  ('important', 365),
#  ('greatest', 365),
#  ('novel', 365),
#  ('expect', 363),
#  ('events', 362),
#  ('robert', 361),
#  ('lady', 360),
#  ('leave', 360),
#  ('self', 360),
#  ('hand', 359),
#  ('run', 359),
#  ('particularly', 359),
#  ('took', 359),
#  ('number', 358),
#  ('enjoyable', 358),
#  ('red', 357),
#  ('heard', 356),
#  ('superb', 354),
#  ('wanted', 351),
#  ('york', 350),
#  ('sound', 350),
#  ('totally', 350),
#  ('writer', 346),
#  ('television', 346),
#  ('head', 346),
#  ('michael', 346),
#  ('tells', 344),
#  ('brother', 343),
#  ('attention', 342),
#  ('song', 341),
#  ('atmosphere', 340),
#  ('change', 339),
#  ('memorable', 339),
#  ('starts', 339),
#  ('mean', 339),
#  ('beauty', 339),
#  ('power', 339),
#  ('country', 339),
#  ('voice', 335),
#  ('modern', 335),
#  ('french', 335),
#  ('miss', 334),
#  ('peter', 334),
#  ('thriller', 331),
#  ('o', 331),
#  ('etc', 330),
#  ('herself', 329),
#  ('problem', 329),
#  ('violence', 329),
#  ('writing', 328),
#  ('realistic', 327),
#  ('killer', 327),
#  ('guys', 327),
#  ('eye', 326),
#  ('room', 325),
#  ('ones', 325),
#  ('career', 324),
#  ('future', 323),
#  ('strange', 323),
#  ('usual', 322),
#  ('alone', 322),
#  ('four', 322),
#  ('class', 322),
#  ('famous', 322),
#  ('taken', 321),
#  ('cannot', 321),
#  ('easy', 321),
#  ('team', 320),
#  ('act', 320),
#  ('sad', 320),
#  ('tale', 319),
#  ('knows', 318),
#  ('richard', 318),
#  ('slow', 317),
#  ('george', 316),
#  ('says', 316),
#  ('b', 315),
#  ('wish', 312),
#  ('taking', 311),
#  ('god', 308),
#  ('usually', 308),
#  ('interest', 308),
#  ('easily', 307),
#  ('joe', 307),
#  ('among', 307),
#  ('comic', 307),
#  ('earth', 307),
#  ('blood', 307),
#  ('stuff', 306),
#  ('sequence', 306),
#  ('perfectly', 305),
#  ('songs', 305),
#  ('kelly', 305),
#  ('believable', 304),
#  ('extremely', 304),
#  ('hit', 304),
#  ('seemed', 303),
#  ('opinion', 303),
#  ('across', 303),
#  ('myself', 303),
#  ('release', 300),
#  ('surprised', 300),
#  ('girls', 300),
#  ('serious', 299),
#  ('order', 299),
#  ('upon', 299),
#  ('powerful', 298),
#  ('meets', 297),
#  ('due', 297),
#  ('stand', 297),
#  ('involved', 297),
#  ('sets', 296),
#  ('happened', 296),
#  ('opening', 295),
#  ('ways', 295),
#  ('hero', 295),
#  ('begins', 295),
#  ('crime', 295),
#  ('brought', 294),
#  ('problems', 293),
#  ('dance', 293),
#  ('working', 293),
#  ('message', 293),
#  ('knew', 292),
#  ('happens', 292),
#  ('period', 291),
#  ('viewing', 291),
#  ('anyway', 290),
#  ('entertainment', 289),
#  ('tries', 289),
#  ('romance', 289),
#  ('theme', 289),
#  ('kill', 288),
#  ('nature', 288),
#  ('kid', 288),
#  ('needs', 287),
#  ('bill', 287),
#  ('similar', 286),
#  ('unique', 286),
#  ('bring', 286),
#  ('japanese', 286),
#  ('certain', 284),
#  ('middle', 284),
#  ('major', 283),
#  ('viewers', 283),
#  ('car', 283),
#  ('running', 283),
#  ('th', 282),
#  ('couldn', 282),
#  ('form', 280),
#  ('exactly', 280),
#  ('thinking', 279),
#  ('level', 279),
#  ('happen', 279),
#  ('mostly', 278),
#  ('killed', 277),
#  ('emotional', 277),
#  ('personal', 277),
#  ('flick', 277),
#  ('talent', 276),
#  ('disney', 276),
#  ('fast', 274),
#  ('era', 274),
#  ('ends', 273),
#  ('lee', 273),
#  ('words', 272),
#  ('stop', 272),
#  ('parents', 272),
#  ('above', 272),
#  ('elements', 272),
#  ('local', 272),
#  ('truth', 272),
#  ('typical', 271),
#  ('started', 271),
#  ('masterpiece', 270),
#  ('whether', 270),
#  ('note', 270),
#  ('dream', 270),
#  ('cut', 269),
#  ('cool', 269),
#  ('guess', 268),
#  ('near', 267),
#  ('within', 266),
#  ('possible', 265),
#  ('brings', 265),
#  ('hours', 265),
#  ('america', 265),
#  ('hour', 264),
#  ('yourself', 264),
#  ('obviously', 264),
#  ('particular', 263),
#  ('creepy', 261),
#  ('became', 261),
#  ('deal', 259),
#  ('clearly', 258),
#  ('beautifully', 258),
#  ('tony', 258),
#  ('sequences', 257),
#  ('de', 257),
#  ('haven', 256),
#  ('society', 255),
#  ('mystery', 255),
#  ('shots', 255),
#  ('giving', 254),
#  ('nearly', 254),
#  ('meet', 253),
#  ('whom', 253),
#  ('portrayal', 252),
#  ('baby', 252),
#  ('william', 251),
#  ('fantasy', 251),
#  ('recommended', 250),
#  ('except', 250),
#  ('means', 250),
#  ('deep', 250),
#  ('indeed', 250),
#  ('fall', 249),
#  ('named', 249),
#  ('eventually', 249),
#  ('feels', 249),
#  ('feature', 249),
#  ('leads', 249),
#  ('married', 249),
#  ('follow', 249),
#  ('situation', 248),
#  ('filmed', 248),
#  ('clear', 248),
#  ('unfortunately', 248),
#  ('five', 248),
#  ('setting', 248),
#  ('animation', 248),
#  ('surprise', 248),
#  ('buy', 247),
#  ('stage', 246),
#  ('please', 246),
#  ('soundtrack', 246),
#  ('street', 245),
#  ('group', 245),
#  ('check', 245),
#  ('dramatic', 244),
#  ('comments', 244),
#  ('poor', 244),
#  ('older', 244),
#  ('political', 244),
#  ('single', 243),
#  ('showing', 243),
#  ('arthur', 243),
#  ('jokes', 242),
#  ('obvious', 242),
#  ('rating', 242),
#  ('present', 242),
#  ('body', 242),
#  ('frank', 242),
#  ('forget', 241),
#  ('wonder', 241),
#  ('turned', 241),
#  ('falls', 240),
#  ('figure', 240),
#  ('appears', 240),
#  ('female', 239),
#  ('learn', 239),
#  ('huge', 238),
#  ('word', 238),
#  ('unlike', 237),
#  ('talk', 237),
#  ('incredible', 237),
#  ('plenty', 237),
#  ('business', 237),
#  ('difficult', 236),
#  ('lots', 236),
#  ('suspense', 234),
#  ('sweet', 234),
#  ('leaves', 233),
#  ('talking', 233),
#  ('gone', 233),
#  ('non', 233),
#  ('subject', 233),
#  ('general', 232),
#  ('rare', 231),
#  ('earlier', 231),
#  ('hell', 230),
#  ('sees', 230),
#  ('touching', 229),
#  ('language', 229),
#  ('sister', 229),
#  ('lack', 229),
#  ('scary', 228),
#  ('solid', 228),
#  ('keeps', 227),
#  ('ben', 227),
#  ('rock', 227),
#  ('straight', 227),
#  ('paris', 227),
#  ('moves', 226),
#  ('terrific', 226),
#  ('recently', 226),
#  ('screenplay', 225),
#  ('popular', 225),
#  ('ten', 225),
#  ('outstanding', 225),
#  ('using', 224),
#  ('portrayed', 224),
#  ('directors', 224),
#  ('various', 224),
#  ('charming', 224),
#  ('manages', 224),
#  ('points', 223),
#  ('inside', 223),
#  ('oh', 222),
#  ('call', 222),
#  ('interested', 221),
#  ('doubt', 220),
#  ('acted', 220),
#  ('leading', 219),
#  ('complete', 218),
#  ('return', 218),
#  ('natural', 218),
#  ('davis', 218),
#  ('dancing', 218),
#  ('add', 217),
#  ('century', 217),
#  ('background', 217),
#  ('features', 217),
#  ('third', 216),
#  ('hear', 216),
#  ('appreciate', 216),
#  ('move', 215),
#  ('realize', 215),
#  ('dr', 215),
#  ('castle', 214),
#  ('cold', 214),
#  ('effective', 214),
#  ('pace', 214),
#  ('none', 213),
#  ('secret', 213),
#  ('towards', 213),
#  ('subtle', 213),
#  ('jane', 212),
#  ('actual', 211),
#  ('tom', 211),
#  ('stewart', 211),
#  ('singing', 211),
#  ('italian', 211),
#  ('material', 210),
#  ('wouldn', 210),
#  ('rate', 209),
#  ('boring', 209),
#  ('filled', 209),
#  ('western', 209),
#  ('familiar', 208),
#  ('decent', 208),
#  ('adventure', 208),
#  ('looked', 207),
#  ('success', 207),
#  ('beyond', 207),
#  ('crazy', 207),
#  ('kept', 206),
#  ('rich', 205),
#  ('sexual', 205),
#  ('touch', 205),
#  ('disappointed', 205),
#  ('free', 205),
#  ('hate', 205),
#  ('social', 205),
#  ('space', 205),
#  ('question', 204),
#  ('plus', 204),
#  ('basically', 204),
#  ('caught', 203),
#  ('public', 203),
#  ('deserves', 203),
#  ('stunning', 203),
#  ('uses', 203),
#  ('impressive', 202),
#  ('aren', 202),
#  ('theater', 202),
#  ('adult', 202),
#  ('expected', 201),
#  ('review', 201),
#  ('supposed', 201),
#  ('visual', 201),
#  ('emotions', 201),
#  ('following', 201),
#  ('awesome', 201),
#  ('telling', 201),
#  ('brothers', 201),
#  ('created', 200),
#  ('victoria', 200),
#  ('saying', 199),
#  ('effect', 199),
#  ('smith', 199),
#  ('die', 199),
#  ('intelligent', 199),
#  ('jim', 199),
#  ('hands', 198),
#  ('u', 198),
#  ('quickly', 198),
#  ('recent', 197),
#  ('worked', 197),
#  ('attempt', 197),
#  ('lovely', 197),
#  ('journey', 197),
#  ('large', 197),
#  ('reviews', 196),
#  ('ok', 196),
#  ('male', 196),
#  ('seriously', 196),
#  ('surprisingly', 196),
#  ('german', 196),
#  ('sinatra', 196),
#  ('create', 195),
#  ('match', 195),
#  ('office', 195),
#  ('fascinating', 195),
#  ('imagine', 195),
#  ('mark', 195),
#  ('exciting', 194),
#  ('welles', 194),
#  ('co', 193),
#  ('feelings', 193),
#  ('pure', 193),
#  ('thanks', 193),
#  ('stay', 193),
#  ('chemistry', 193),
#  ('copy', 193),
#  ('themes', 193),
#  ('laughs', 193),
#  ('begin', 192),
#  ('master', 192),
#  ('complex', 192),
#  ('odd', 191),
#  ('open', 191),
#  ('spirit', 191),
#  ('detective', 191),
#  ('reasons', 191),
#  ('previous', 190),
#  ('fairly', 190),
#  ('air', 190),
#  ('reading', 189),
#  ('audiences', 189),
#  ('storyline', 189),
#  ('minute', 189),
#  ('produced', 189),
#  ('hot', 188),
#  ('dreams', 188),
#  ('somehow', 188),
#  ('mary', 188),
#  ('dog', 188),
#  ('prison', 188),
#  ('needed', 187),
#  ('break', 187),
#  ('wonderfully', 187),
#  ('studio', 187),
#  ('casting', 186),
#  ('win', 186),
#  ('gore', 186),
#  ('mention', 186),
#  ('battle', 186),
#  ('fighting', 185),
#  ('members', 185),
#  ('starring', 185),
#  ('award', 185),
#  ...]

# %%
negative_counts.most_common()
# Out:
# [('', 347719),
#  ('.', 104363),
#  ('the', 100615),
#  ('a', 48964),
#  ('and', 46159),
#  ('of', 42887),
#  ('to', 42793),
#  ('br', 32259),
#  ('is', 31116),
#  ('it', 29924),
#  ('i', 29180),
#  ('in', 27172),
#  ('this', 25420),
#  ('that', 23344),
#  ('s', 19511),
#  ('was', 16292),
#  ('movie', 15417),
#  ('for', 13597),
#  ('but', 13538),
#  ('with', 12950),
#  ('as', 12857),
#  ('t', 12517),
#  ('film', 11547),
#  ('you', 10944),
#  ('on', 10650),
#  ('not', 10289),
#  ('have', 9466),
#  ('are', 9143),
#  ('be', 9095),
#  ('he', 8644),
#  ('one', 8112),
#  ('they', 8058),
#  ('at', 7648),
#  ('his', 7562),
#  ('all', 7480),
#  ('so', 7161),
#  ('like', 6995),
#  ('there', 6614),
#  ('just', 6578),
#  ('by', 6553),
#  ('an', 6421),
#  ('or', 6380),
#  ('who', 6131),
#  ('if', 6006),
#  ('from', 5977),
#  ('about', 5569),
#  ('out', 5491),
#  ('what', 5262),
#  ('some', 5199),
#  ('no', 5048),
#  ('her', 5021),
#  ('can', 4769),
#  ('has', 4704),
#  ('even', 4668),
#  ('good', 4623),
#  ('bad', 4509),
#  ('would', 4418),
#  ('up', 4235),
#  ('more', 4220),
#  ('only', 4200),
#  ('when', 4195),
#  ('she', 4088),
#  ('really', 3898),
#  ('time', 3866),
#  ('had', 3833),
#  ('my', 3784),
#  ('were', 3749),
#  ('very', 3609),
#  ('which', 3559),
#  ('me', 3500),
#  ('see', 3420),
#  ('don', 3334),
#  ('their', 3285),
#  ('do', 3243),
#  ('we', 3224),
#  ('than', 3183),
#  ('been', 3168),
#  ('much', 3167),
#  ('get', 3157),
#  ('story', 3144),
#  ('because', 3074),
#  ('people', 2990),
#  ('then', 2941),
#  ('could', 2915),
#  ('how', 2895),
#  ('make', 2889),
#  ('any', 2882),
#  ('made', 2805),
#  ('into', 2742),
#  ('first', 2689),
#  ('other', 2643),
#  ('well', 2630),
#  ('too', 2611),
#  ('them', 2610),
#  ('plot', 2561),
#  ('movies', 2559),
#  ('way', 2504),
#  ('will', 2502),
#  ('acting', 2452),
#  ('most', 2427),
#  ('him', 2410),
#  ('after', 2393),
#  ('think', 2313),
#  ('its', 2279),
#  ('watch', 2243),
#  ('also', 2219),
#  ('character', 2209),
#  ('off', 2202),
#  ('did', 2198),
#  ('characters', 2194),
#  ('why', 2173),
#  ('know', 2081),
#  ('being', 2068),
#  ('better', 2056),
#  ('over', 2036),
#  ('never', 2029),
#  ('seen', 2003),
#  ('ever', 1983),
#  ('your', 1982),
#  ('show', 1978),
#  ('two', 1967),
#  ('where', 1965),
#  ('films', 1921),
#  ('little', 1921),
#  ('should', 1849),
#  ('say', 1845),
#  ('many', 1840),
#  ('nothing', 1839),
#  ('m', 1827),
#  ('here', 1822),
#  ('does', 1796),
#  ('end', 1769),
#  ('scene', 1746),
#  ('something', 1743),
#  ('thing', 1742),
#  ('ve', 1720),
#  ('these', 1701),
#  ('scenes', 1699),
#  ('great', 1676),
#  ('go', 1672),
#  ('doesn', 1641),
#  ('re', 1639),
#  ('watching', 1627),
#  ('didn', 1612),
#  ('man', 1599),
#  ('such', 1590),
#  ('through', 1565),
#  ('life', 1524),
#  ('back', 1510),
#  ('while', 1509),
#  ('actually', 1506),
#  ('director', 1504),
#  ('worst', 1503),
#  ('funny', 1481),
#  ('actors', 1466),
#  ('now', 1432),
#  ('going', 1420),
#  ('still', 1414),
#  ('look', 1409),
#  ('old', 1386),
#  ('those', 1384),
#  ('love', 1378),
#  ('few', 1375),
#  ('before', 1360),
#  ('another', 1346),
#  ('want', 1332),
#  ('real', 1330),
#  ('best', 1317),
#  ('minutes', 1299),
#  ('same', 1295),
#  ('though', 1287),
#  ('pretty', 1282),
#  ('every', 1274),
#  ('script', 1273),
#  ('work', 1269),
#  ('least', 1255),
#  ('seems', 1249),
#  ('enough', 1233),
#  ('down', 1232),
#  ('part', 1224),
#  ('got', 1214),
#  ('original', 1203),
#  ('horror', 1191),
#  ('around', 1190),
#  ('d', 1182),
#  ('guy', 1178),
#  ('lot', 1173),
#  ('fact', 1168),
#  ('new', 1165),
#  ('things', 1151),
#  ('point', 1141),
#  ('take', 1139),
#  ('find', 1133),
#  ('again', 1129),
#  ('give', 1122),
#  ('anything', 1120),
#  ('makes', 1119),
#  ('thought', 1116),
#  ('however', 1115),
#  ('isn', 1112),
#  ('long', 1104),
#  ('whole', 1090),
#  ('years', 1079),
#  ('cast', 1067),
#  ('money', 1055),
#  ('big', 1052),
#  ('making', 1046),
#  ('gets', 1039),
#  ('might', 1038),
#  ('interesting', 1008),
#  ('action', 1005),
#  ('come', 1003),
#  ('almost', 997),
#  ('right', 994),
#  ('us', 994),
#  ('without', 985),
#  ('far', 977),
#  ('awful', 975),
#  ('quite', 971),
#  ('must', 971),
#  ('kind', 965),
#  ('ll', 962),
#  ('reason', 954),
#  ('am', 949),
#  ('comedy', 947),
#  ('done', 946),
#  ('someone', 935),
#  ('away', 935),
#  ('saw', 927),
#  ('looks', 921),
#  ('trying', 920),
#  ('tv', 919),
#  ('poor', 917),
#  ('believe', 898),
#  ('hard', 897),
#  ('let', 896),
#  ('boring', 895),
#  ('wasn', 895),
#  ('world', 893),
#  ('instead', 885),
#  ('anyone', 884),
#  ('sure', 882),
#  ('terrible', 880),
#  ('girl', 880),
#  ('effects', 876),
#  ('probably', 876),
#  ('may', 873),
#  ('maybe', 864),
#  ('feel', 861),
#  ('times', 861),
#  ('stupid', 859),
#  ('own', 854),
#  ('last', 852),
#  ('series', 851),
#  ('waste', 850),
#  ('since', 841),
#  ('looking', 840),
#  ('rather', 825),
#  ('woman', 820),
#  ('young', 818),
#  ('music', 812),
#  ('between', 812),
#  ('idea', 811),
#  ('bit', 811),
#  ('half', 811),
#  ('book', 808),
#  ('put', 797),
#  ('found', 794),
#  ('family', 791),
#  ('sense', 777),
#  ('budget', 774),
#  ('having', 773),
#  ('low', 762),
#  ('worse', 759),
#  ('everything', 756),
#  ('goes', 755),
#  ('wrong', 753),
#  ('said', 750),
#  ('comes', 749),
#  ('else', 747),
#  ('main', 747),
#  ('course', 743),
#  ('supposed', 743),
#  ('either', 741),
#  ('role', 741),
#  ('audience', 735),
#  ('completely', 728),
#  ('yet', 727),
#  ('actor', 726),
#  ('set', 724),
#  ('day', 723),
#  ('screen', 719),
#  ('watched', 719),
#  ('always', 719),
#  ('ending', 714),
#  ('seem', 703),
#  ('left', 698),
#  ('shot', 698),
#  ('simply', 697),
#  ('special', 693),
#  ('read', 687),
#  ('place', 681),
#  ('both', 676),
#  ('black', 674),
#  ('mean', 671),
#  ('less', 670),
#  ('horrible', 669),
#  ('year', 668),
#  ('house', 664),
#  ('high', 663),
#  ('three', 657),
#  ('once', 656),
#  ('try', 654),
#  ('worth', 653),
#  ('although', 648),
#  ('line', 645),
#  ('sex', 641),
#  ('couldn', 640),
#  ('oh', 636),
#  ('dvd', 636),
#  ('our', 633),
#  ('version', 631),
#  ('dead', 631),
#  ('video', 630),
#  ('american', 628),
#  ('rest', 627),
#  ('everyone', 624),
#  ('production', 622),
#  ('seeing', 622),
#  ('night', 612),
#  ('women', 610),
#  ('kids', 608),
#  ('play', 607),
#  ('fun', 607),
#  ('second', 606),
#  ('played', 606),
#  ('used', 606),
#  ('during', 604),
#  ('mind', 604),
#  ('star', 603),
#  ('camera', 603),
#  ('together', 602),
#  ('dialogue', 600),
#  ('given', 597),
#  ('each', 596),
#  ('need', 594),
#  ('tell', 592),
#  ('head', 589),
#  ('takes', 584),
#  ('especially', 584),
#  ('problem', 584),
#  ('couple', 583),
#  ('name', 578),
#  ('death', 576),
#  ('fan', 573),
#  ('doing', 573),
#  ('shows', 572),
#  ('use', 571),
#  ('wife', 568),
#  ('performance', 566),
#  ('himself', 564),
#  ('start', 560),
#  ('help', 553),
#  ('different', 549),
#  ('sort', 549),
#  ('lines', 549),
#  ('guess', 548),
#  ('unfortunately', 547),
#  ('home', 547),
#  ('getting', 547),
#  ('next', 547),
#  ('nice', 546),
#  ('short', 543),
#  ('written', 541),
#  ('killer', 541),
#  ('hollywood', 540),
#  ('crap', 538),
#  ('understand', 537),
#  ('piece', 533),
#  ('seemed', 531),
#  ('yes', 531),
#  ('entire', 527),
#  ('later', 526),
#  ('school', 525),
#  ('true', 524),
#  ('plays', 521),
#  ('case', 520),
#  ('decent', 518),
#  ('person', 518),
#  ('care', 517),
#  ('absolutely', 515),
#  ('sound', 509),
#  ('along', 507),
#  ('felt', 507),
#  ('keep', 506),
#  ('job', 506),
#  ('perhaps', 506),
#  ('stars', 505),
#  ('john', 505),
#  ('tries', 504),
#  ('flick', 501),
#  ('blood', 501),
#  ('went', 497),
#  ('full', 496),
#  ('men', 494),
#  ('title', 494),
#  ('top', 492),
#  ('annoying', 490),
#  ('face', 488),
#  ('laugh', 487),
#  ('until', 486),
#  ('friends', 486),
#  ('came', 483),
#  ('evil', 483),
#  ('lost', 479),
#  ('writing', 479),
#  ('itself', 478),
#  ('ridiculous', 475),
#  ('save', 474),
#  ('won', 474),
#  ('example', 473),
#  ('kill', 472),
#  ('war', 472),
#  ('wanted', 470),
#  ('god', 470),
#  ('hour', 468),
#  ('thinking', 468),
#  ('act', 468),
#  ('totally', 468),
#  ('called', 466),
#  ('car', 465),
#  ('direction', 463),
#  ('obviously', 463),
#  ('guys', 459),
#  ('except', 459),
#  ('attempt', 456),
#  ('already', 456),
#  ('b', 455),
#  ('gore', 455),
#  ('truly', 454),
#  ('playing', 444),
#  ('etc', 443),
#  ('episode', 443),
#  ('remember', 441),
#  ('white', 440),
#  ('recommend', 439),
#  ('please', 437),
#  ('wouldn', 432),
#  ('lack', 431),
#  ('boy', 428),
#  ('hand', 428),
#  ('moments', 427),
#  ('turn', 427),
#  ('cheap', 427),
#  ('against', 423),
#  ('ok', 422),
#  ('early', 422),
#  ('obvious', 421),
#  ('fans', 421),
#  ('myself', 421),
#  ('lead', 421),
#  ('stuff', 420),
#  ('killed', 420),
#  ('quality', 419),
#  ('enjoy', 417),
#  ('hope', 417),
#  ('kid', 416),
#  ('wonder', 416),
#  ('looked', 414),
#  ('hell', 414),
#  ('run', 412),
#  ('style', 412),
#  ('seriously', 411),
#  ('certainly', 411),
#  ('children', 411),
#  ('starts', 410),
#  ('complete', 409),
#  ('based', 408),
#  ('others', 408),
#  ('under', 407),
#  ('none', 407),
#  ('dull', 404),
#  ('self', 402),
#  ('finally', 402),
#  ('happens', 400),
#  ('beginning', 400),
#  ('apparently', 399),
#  ('live', 399),
#  ('becomes', 396),
#  ('human', 396),
#  ('anyway', 395),
#  ('despite', 395),
#  ('picture', 395),
#  ('lame', 395),
#  ('slow', 393),
#  ('poorly', 393),
#  ('close', 392),
#  ('gave', 387),
#  ('mr', 387),
#  ('cut', 386),
#  ('saying', 386),
#  ('become', 385),
#  ('final', 385),
#  ('happened', 384),
#  ('predictable', 384),
#  ('overall', 384),
#  ('several', 383),
#  ('writer', 383),
#  ('mother', 381),
#  ('father', 381),
#  ('silly', 379),
#  ('actress', 378),
#  ('expect', 377),
#  ('beautiful', 375),
#  ('call', 375),
#  ('zombie', 375),
#  ('behind', 374),
#  ('friend', 373),
#  ('small', 372),
#  ('stop', 372),
#  ('cannot', 370),
#  ('avoid', 369),
#  ('hours', 368),
#  ('themselves', 367),
#  ('cinema', 366),
#  ('michael', 365),
#  ('fight', 365),
#  ('interest', 365),
#  ('days', 365),
#  ('classic', 364),
#  ('entertaining', 362),
#  ('humor', 359),
#  ('jokes', 359),
#  ('bunch', 358),
#  ('often', 358),
#  ('daughter', 357),
#  ('wants', 357),
#  ('heard', 357),
#  ('girls', 356),
#  ('directed', 354),
#  ('running', 352),
#  ('rating', 352),
#  ('throughout', 352),
#  ('liked', 351),
#  ('disappointed', 351),
#  ('police', 351),
#  ('sorry', 350),
#  ('says', 349),
#  ('badly', 349),
#  ('word', 348),
#  ('side', 348),
#  ('hero', 346),
#  ('eyes', 346),
#  ('extremely', 345),
#  ('type', 345),
#  ('son', 344),
#  ('past', 344),
#  ('viewer', 343),
#  ('yourself', 342),
#  ('mess', 342),
#  ('female', 342),
#  ('talking', 341),
#  ('gives', 341),
#  ('alone', 341),
#  ('parts', 341),
#  ('body', 339),
#  ('child', 339),
#  ('single', 339),
#  ('drama', 338),
#  ('possible', 338),
#  ('art', 337),
#  ('definitely', 337),
#  ('turns', 337),
#  ('violence', 336),
#  ('started', 336),
#  ('involved', 335),
#  ('weak', 335),
#  ('matter', 335),
#  ('took', 334),
#  ('non', 334),
#  ('history', 334),
#  ('performances', 333),
#  ('group', 333),
#  ('shots', 332),
#  ('aren', 332),
#  ('exactly', 332),
#  ('turned', 329),
#  ('basically', 329),
#  ('able', 329),
#  ('happen', 329),
#  ('talent', 326),
#  ('scary', 325),
#  ('usually', 324),
#  ('straight', 323),
#  ('serious', 323),
#  ('rent', 323),
#  ('feeling', 322),
#  ('editing', 322),
#  ('review', 322),
#  ('genre', 321),
#  ('hit', 318),
#  ('dark', 317),
#  ('coming', 315),
#  ('soon', 315),
#  ('unless', 314),
#  ('clearly', 313),
#  ('huge', 312),
#  ('voice', 312),
#  ('order', 311),
#  ('cool', 311),
#  ('leave', 311),
#  ('beyond', 310),
#  ('stay', 309),
#  ('tried', 309),
#  ('middle', 307),
#  ('minute', 307),
#  ('zombies', 306),
#  ('level', 305),
#  ('falls', 302),
#  ('dumb', 302),
#  ('sequel', 301),
#  ('five', 300),
#  ('effort', 300),
#  ('sad', 299),
#  ('earth', 299),
#  ('told', 299),
#  ('ends', 298),
#  ('fails', 298),
#  ('major', 297),
#  ('king', 296),
#  ('particularly', 296),
#  ('known', 295),
#  ('joke', 295),
#  ('mention', 295),
#  ('storyline', 294),
#  ('late', 294),
#  ('opening', 293),
#  ('lives', 293),
#  ('whatever', 293),
#  ('appears', 293),
#  ('wasted', 293),
#  ('across', 291),
#  ('words', 291),
#  ('moment', 291),
#  ('stories', 291),
#  ('space', 291),
#  ('taken', 290),
#  ('taking', 290),
#  ('fine', 290),
#  ('sometimes', 289),
#  ('english', 289),
#  ('mostly', 288),
#  ('experience', 288),
#  ('write', 288),
#  ('town', 288),
#  ('talk', 285),
#  ('dialog', 284),
#  ('okay', 284),
#  ('pointless', 283),
#  ('room', 281),
#  ('premise', 280),
#  ('points', 279),
#  ('chance', 279),
#  ('imagine', 279),
#  ('fast', 278),
#  ('career', 278),
#  ('living', 278),
#  ('die', 278),
#  ('four', 278),
#  ('hate', 277),
#  ('o', 276),
#  ('game', 276),
#  ('killing', 275),
#  ('easily', 275),
#  ('giving', 274),
#  ('problems', 273),
#  ('ten', 273),
#  ('opinion', 273),
#  ('usual', 272),
#  ('flat', 272),
#  ('murder', 271),
#  ('shown', 270),
#  ('somehow', 270),
#  ('nudity', 270),
#  ('husband', 270),
#  ('using', 269),
#  ('wish', 269),
#  ('number', 269),
#  ('total', 268),
#  ('ones', 267),
#  ('add', 266),
#  ('roles', 266),
#  ('general', 265),
#  ('class', 265),
#  ('bring', 265),
#  ('actual', 265),
#  ('feels', 265),
#  ('somewhat', 265),
#  ('lots', 264),
#  ('theater', 264),
#  ('material', 264),
#  ('lady', 263),
#  ('age', 263),
#  ('sit', 262),
#  ('change', 262),
#  ('local', 262),
#  ('otherwise', 261),
#  ('strange', 261),
#  ('due', 261),
#  ('lee', 260),
#  ('works', 260),
#  ('reviews', 260),
#  ('whose', 260),
#  ('ago', 259),
#  ('sets', 259),
#  ('upon', 259),
#  ('plain', 258),
#  ('released', 258),
#  ('cinematography', 257),
#  ('nor', 257),
#  ('cheesy', 257),
#  ('average', 257),
#  ('needs', 257),
#  ('monster', 256),
#  ('rock', 256),
#  ('ask', 256),
#  ('documentary', 256),
#  ('mystery', 256),
#  ('free', 255),
#  ('doubt', 255),
#  ('vampire', 255),
#  ('writers', 254),
#  ('power', 254),
#  ('possibly', 254),
#  ('expected', 253),
#  ('wait', 253),
#  ('footage', 252),
#  ('including', 252),
#  ('song', 252),
#  ('knew', 252),
#  ('city', 252),
#  ('kept', 252),
#  ('thriller', 251),
#  ('brother', 250),
#  ('figure', 250),
#  ('whether', 250),
#  ('garbage', 250),
#  ('reality', 249),
#  ('james', 248),
#  ('comic', 248),
#  ('above', 248),
#  ('nearly', 248),
#  ('development', 247),
#  ('bored', 246),
#  ('pathetic', 245),
#  ('decided', 245),
#  ('near', 244),
#  ('needed', 244),
#  ('hot', 244),
#  ('trash', 243),
#  ('perfect', 242),
#  ('view', 241),
#  ('laughs', 241),
#  ('gone', 241),
#  ('forced', 241),
#  ('imdb', 241),
#  ('cop', 241),
#  ('knows', 241),
#  ('buy', 241),
#  ('shame', 240),
#  ('country', 239),
#  ('within', 239),
#  ('modern', 238),
#  ('credits', 237),
#  ('entertainment', 237),
#  ('clear', 237),
#  ('laughable', 237),
#  ('box', 236),
#  ('question', 236),
#  ('potential', 236),
#  ('novel', 236),
#  ('check', 235),
#  ('richard', 235),
#  ('songs', 234),
#  ('score', 234),
#  ('move', 234),
#  ('spent', 234),
#  ('means', 233),
#  ('meant', 233),
#  ('haven', 232),
#  ('important', 232),
#  ('heart', 231),
#  ('directing', 231),
#  ('filmed', 231),
#  ('christmas', 231),
#  ('miss', 230),
#  ('comments', 229),
#  ('male', 228),
#  ('excellent', 227),
#  ('hear', 227),
#  ('fake', 227),
#  ('hilarious', 226),
#  ('fall', 226),
#  ('sequence', 225),
#  ('message', 225),
#  ('failed', 225),
#  ('events', 225),
#  ('pay', 225),
#  ('stand', 225),
#  ('television', 225),
#  ('enjoyed', 224),
#  ('typical', 224),
#  ('feature', 224),
#  ('showing', 224),
#  ('working', 223),
#  ('ideas', 222),
#  ('forward', 222),
#  ('attention', 222),
#  ('result', 222),
#  ('incredibly', 221),
#  ('apart', 221),
#  ('third', 220),
#  ('musical', 220),
#  ('happy', 219),
#  ('comment', 219),
#  ('sounds', 219),
#  ('jack', 218),
#  ('forget', 218),
#  ('attempts', 218),
#  ('filmmakers', 218),
#  ('elements', 218),
#  ('similar', 218),
#  ('dr', 218),
#  ('neither', 217),
#  ('sister', 217),
#  ('sexual', 217),
#  ('begin', 217),
#  ('walk', 217),
#  ('named', 217),
#  ('barely', 216),
#  ('girlfriend', 216),
#  ('finds', 216),
#  ('japanese', 216),
#  ('reading', 216),
#  ('british', 216),
#  ('robert', 215),
#  ('period', 215),
#  ('red', 215),
#  ('hardly', 215),
#  ('acted', 215),
#  ('spoilers', 215),
#  ('light', 214),
#  ('open', 214),
#  ('leads', 213),
#  ('appear', 213),
#  ('list', 213),
#  ('disappointing', 213),
#  ('unbelievable', 213),
#  ('follow', 213),
#  ('cover', 213),
#  ('viewers', 212),
#  ('eye', 212),
#  ('david', 212),
#  ('admit', 212),
#  ('producers', 211),
#  ('ways', 211),
#  ('wrote', 211),
#  ('sadly', 211),
#  ('bother', 211),
#  ('weird', 210),
#  ('sequences', 210),
#  ('weren', 210),
#  ('gun', 210),
#  ('dog', 210),
#  ('directors', 209),
#  ('value', 209),
#  ('baby', 207),
#  ('fire', 207),
#  ('simple', 207),
#  ('concept', 207),
#  ('eventually', 206),
#  ('street', 206),
#  ('screenplay', 205),
#  ('dance', 205),
#  ('tom', 205),
#  ('loved', 205),
#  ('surprise', 205),
#  ('form', 204),
#  ('plus', 204),
#  ('previous', 204),
#  ('worked', 204),
#  ('herself', 204),
#  ('remake', 204),
#  ('animation', 203),
#  ('rate', 203),
#  ('sick', 203),
#  ('th', 203),
#  ('crazy', 202),
#  ('air', 202),
#  ('suspense', 202),
#  ('utterly', 202),
#  ('tells', 202),
#  ('expecting', 202),
#  ('strong', 201),
#  ('george', 200),
#  ('e', 200),
#  ('today', 200),
#  ('grade', 199),
#  ('doctor', 199),
#  ('casting', 199),
#  ('positive', 198),
#  ('certain', 198),
#  ('disappointment', 198),
#  ('redeeming', 198),
#  ('team', 198),
#  ('excuse', 198),
#  ('crime', 198),
#  ('biggest', 197),
#  ('considering', 197),
#  ('kills', 197),
#  ('fighting', 197),
#  ('episodes', 197),
#  ('shoot', 197),
#  ('honestly', 197),
#  ('wonderful', 196),
#  ('effect', 196),
#  ('yeah', 196),
#  ('subject', 195),
#  ('naked', 195),
#  ('twist', 195),
#  ('brain', 195),
#  ('channel', 195),
#  ('gay', 194),
#  ('quickly', 194),
#  ('bill', 194),
#  ('create', 193),
#  ('c', 193),
#  ('supporting', 193),
#  ('learn', 193),
#  ('background', 192),
#  ('theme', 192),
#  ('sci', 192),
#  ('spend', 192),
#  ('cause', 192),
#  ('f', 191),
#  ('truth', 191),
#  ('talented', 191),
#  ('suddenly', 191),
#  ('fi', 191),
#  ('hands', 191),
#  ('among', 191),
#  ('relationship', 191),
#  ('de', 191),
#  ('stage', 191),
#  ('future', 190),
#  ('begins', 190),
#  ('america', 189),
#  ('island', 188),
#  ('makers', 188),
#  ('painful', 188),
#  ('surprised', 188),
#  ('accent', 188),
#  ('nowhere', 188),
#  ('deal', 188),
#  ('break', 188),
#  ('soundtrack', 188),
#  ('batman', 188),
#  ('mark', 188),
#  ('indeed', 187),
#  ('porn', 187),
#  ('peter', 186),
#  ('interested', 186),
#  ('odd', 185),
#  ('mediocre', 185),
#  ('fairly', 185),
#  ('disney', 185),
#  ('mad', 185),
#  ('somewhere', 185),
#  ('crew', 184),
#  ('earlier', 184),
#  ('project', 184),
#  ('mentioned', 184),
#  ('wooden', 183),
#  ('difficult', 183),
#  ('leaves', 183),
#  ('ended', 183),
#  ('note', 183),
#  ('explain', 183),
#  ('stick', 182),
#  ('realize', 182),
#  ('famous', 182),
#  ('store', 182),
#  ('missing', 181),
#  ('became', 181),
#  ('speak', 181),
#  ('hold', 181),
#  ('release', 181),
#  ('waiting', 181),
#  ('cute', 181),
#  ('bottom', 180),
#  ...]

# %%
pos_neg_ratios = Counter()

for term,cnt in list(total_counts.most_common()):
  if(cnt > 100):
      pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
      pos_neg_ratios[term] = pos_neg_ratio

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0767372982428243
# Pos-to-neg ratio for 'amazing' = 3.791411042944785
# Pos-to-neg ratio for 'terrible' = 0.1782065834279228

# %%
for word,ratio in pos_neg_ratios.most_common():
    pos_neg_ratios[word] = np.log(ratio)

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.07393544849785144
# Pos-to-neg ratio for 'amazing' = 1.3327382566509285
# Pos-to-neg ratio for 'terrible' = -1.7248118205878715

# %%
vocab = set(total_counts.keys())

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 60607

# %%
layer_0 = np.zeros((1,vocab_size))

# %%
word2index = {}

# %%
for i,word in enumerate(vocab):
    word2index[word] = i

# %%
word2index
# Out:
# {'': 0,
#  'eaves': 1,
#  'barrie': 2,
#  'evasion': 3,
#  'trifiri': 4,
#  'alejandra': 5,
#  'alert': 6,
#  'putzi': 7,
#  'sexton': 8,
#  'wince': 9,
#  'director': 10,
#  'busia': 11,
#  'cipriani': 12,
#  'yoshio': 13,
#  'fascists': 14,
#  'dumber': 15,
#  'abolitionists': 16,
#  'screamer': 17,
#  'hosing': 18,
#  'bumblebee': 19,
#  'meeuwsen': 20,
#  'spradlin': 21,
#  'grafted': 22,
#  'pinoy': 23,
#  'pt': 24,
#  'revue': 25,
#  'manticores': 26,
#  'inexorably': 27,
#  'aod': 28,
#  'celebrate': 29,
#  'penlight': 30,
#  'crummiest': 31,
#  'yelchin': 32,
#  'riser': 33,
#  'rumore': 34,
#  'zorak': 35,
#  'undisputed': 36,
#  'spinster': 37,
#  'podium': 38,
#  'yojiro': 39,
#  'promised': 40,
#  'unsees': 41,
#  'vermette': 42,
#  'caselli': 43,
#  'bt': 44,
#  'pontiac': 45,
#  'oughta': 46,
#  'susie': 47,
#  'release': 48,
#  'programme': 49,
#  'brats': 50,
#  'mcparland': 51,
#  'homing': 52,
#  'lino': 53,
#  'content': 54,
#  'keeper': 55,
#  'schlosser': 56,
#  'enigmas': 57,
#  'petto': 58,
#  'cancellation': 59,
#  'arrondissements': 60,
#  'jullian': 61,
#  'dsds': 62,
#  'muscleman': 63,
#  'upstart': 64,
#  'suffering': 65,
#  'surfed': 66,
#  'counterfeit': 67,
#  'willing': 68,
#  'ales': 69,
#  'type': 70,
#  'suchlike': 71,
#  'rejoiced': 72,
#  'copiously': 73,
#  'mixing': 74,
#  'gia': 75,
#  'said': 76,
#  'helmer': 77,
#  'trevor': 78,
#  'didnt': 79,
#  'trivialising': 80,
#  'documentarist': 81,
#  'ejaculations': 82,
#  'marabre': 83,
#  'sakes': 84,
#  'guidance': 85,
#  'permission': 86,
#  'annihilator': 87,
#  'goryuy': 88,
#  'answers': 89,
#  'tapeheads': 90,
#  'compatible': 91,
#  'maki': 92,
#  'gisbourne': 93,
#  'proven': 94,
#  'treks': 95,
#  'pejorative': 96,
#  'callahan': 97,
#  'hammill': 98,
#  'cliff': 99,
#  'lira': 100,
#  'fallin': 101,
#  'bick': 102,
#  'mutate': 103,
#  'stockholm': 104,
#  'fenech': 105,
#  'fatone': 106,
#  'resurrections': 107,
#  'figurine': 108,
#  'shakespere': 109,
#  'colonel': 110,
#  'auteurist': 111,
#  'cookbook': 112,
#  'manhunt': 113,
#  'nasties': 114,
#  'standstill': 115,
#  'mercurio': 116,
#  'diseased': 117,
#  'antithesis': 118,
#  'lobbyist': 119,
#  'alongs': 120,
#  'violated': 121,
#  'beech': 122,
#  'chadha': 123,
#  'stockroom': 124,
#  'clementine': 125,
#  'genghis': 126,
#  'guttman': 127,
#  'modernized': 128,
#  'sleek': 129,
#  'mutters': 130,
#  'pascualino': 131,
#  'literature': 132,
#  'englishwoman': 133,
#  'haves': 134,
#  'moonlight': 135,
#  'extrapolating': 136,
#  'array': 137,
#  'gallagher': 138,
#  'chant': 139,
#  'grossness': 140,
#  'cums': 141,
#  'operahouse': 142,
#  'pedant': 143,
#  'skinflint': 144,
#  'possesing': 145,
#  'park': 146,
#  'evacuate': 147,
#  'halifax': 148,
#  'prank': 149,
#  'operation': 150,
#  'workmate': 151,
#  'dread': 152,
#  'izo': 153,
#  'destruct': 154,
#  'lastliberal': 155,
#  'bead': 156,
#  'clmenti': 157,
#  'cruiser': 158,
#  'poor': 159,
#  'transforming': 160,
#  'wiping': 161,
#  'wii': 162,
#  'cajun': 163,
#  'gaffikin': 164,
#  'envisioning': 165,
#  'adversaries': 166,
#  'infestation': 167,
#  'unknowns': 168,
#  'hypocrisy': 169,
#  'stereotyping': 170,
#  'must': 171,
#  'turpentine': 172,
#  'hallucination': 173,
#  'stockbroker': 174,
#  'kna': 175,
#  'gokbakar': 176,
#  'brighten': 177,
#  'grunge': 178,
#  'alives': 179,
#  'beautifule': 180,
#  'anglo': 181,
#  'night': 182,
#  'mishin': 183,
#  'djs': 184,
#  'prepon': 185,
#  'sneaking': 186,
#  'enoughand': 187,
#  'dorsal': 188,
#  'sndtrk': 189,
#  'labels': 190,
#  'santacruz': 191,
#  'tamil': 192,
#  'hornby': 193,
#  'pembrook': 194,
#  'melty': 195,
#  'thaddeus': 196,
#  'narasimhan': 197,
#  'seduction': 198,
#  'educating': 199,
#  'sensationalized': 200,
#  'arts': 201,
#  'chirp': 202,
#  'diabolism': 203,
#  'failings': 204,
#  'mobius': 205,
#  'dower': 206,
#  'duper': 207,
#  'glares': 208,
#  'underscore': 209,
#  'chattarjee': 210,
#  'harshness': 211,
#  'nada': 212,
#  'halted': 213,
#  'membership': 214,
#  'claims': 215,
#  'deposed': 216,
#  'exorbitant': 217,
#  'lamonte': 218,
#  'exploiting': 219,
#  'citywide': 220,
#  'maldeamores': 221,
#  'evel': 222,
#  'contamination': 223,
#  'torazo': 224,
#  'nonflammable': 225,
#  'qualitatively': 226,
#  'nallae': 227,
#  'timeline': 228,
#  'grievances': 229,
#  'lodged': 230,
#  'emission': 231,
#  'cocaine': 232,
#  'wooing': 233,
#  'freke': 234,
#  'katja': 235,
#  'heartstopping': 236,
#  'ragneks': 237,
#  'spheerhead': 238,
#  'histories': 239,
#  'decayed': 240,
#  'ignoring': 241,
#  'mountaineering': 242,
#  'eyes': 243,
#  'sensory': 244,
#  'propagate': 245,
#  'dza': 246,
#  'tip': 247,
#  'cases': 248,
#  'desu': 249,
#  'demeans': 250,
#  'lafferty': 251,
#  'numinous': 252,
#  'grove': 253,
#  'enachanted': 254,
#  'wavered': 255,
#  'zinn': 256,
#  'zadora': 257,
#  'unseen': 258,
#  'sensous': 259,
#  'tmtm': 260,
#  'congratulatory': 261,
#  'poppy': 262,
#  'naturalism': 263,
#  'czechia': 264,
#  'doppelganger': 265,
#  'weeknight': 266,
#  'moriarty': 267,
#  'manana': 268,
#  'arggh': 269,
#  'mcgarten': 270,
#  'draza': 271,
#  'not': 272,
#  'exhibitions': 273,
#  'timely': 274,
#  'mumbo': 275,
#  'cogent': 276,
#  'boomerang': 277,
#  'increasingly': 278,
#  'unknowing': 279,
#  'chesty': 280,
#  'jasna': 281,
#  'airheadedness': 282,
#  'storywriter': 283,
#  'taing': 284,
#  'welshman': 285,
#  'shiraki': 286,
#  'reared': 287,
#  'swiztertland': 288,
#  'loather': 289,
#  'bertrand': 290,
#  'deduce': 291,
#  'versacorps': 292,
#  'conglomeration': 293,
#  'dearth': 294,
#  'det': 295,
#  'lovelace': 296,
#  'expurgated': 297,
#  'thief': 298,
#  'witches': 299,
#  'lowsy': 300,
#  'cineliterate': 301,
#  'amour': 302,
#  'etre': 303,
#  'essenay': 304,
#  'disputing': 305,
#  'bhajpai': 306,
#  'arvidson': 307,
#  'sowwy': 308,
#  'surfs': 309,
#  'verica': 310,
#  'yup': 311,
#  'mindlessly': 312,
#  'evocative': 313,
#  'professor': 314,
#  'mesmerizes': 315,
#  'goofy': 316,
#  'silence': 317,
#  'word': 318,
#  'washoe': 319,
#  'emasculating': 320,
#  'spinelessness': 321,
#  'adriatic': 322,
#  'mutineer': 323,
#  'list': 324,
#  'incrementally': 325,
#  'claudie': 326,
#  'shortlived': 327,
#  'ritual': 328,
#  'routs': 329,
#  'sentimentality': 330,
#  'policticly': 331,
#  'cohesive': 332,
#  'sumpthin': 333,
#  'heartbreaking': 334,
#  'gershuni': 335,
#  'pair': 336,
#  'criticizing': 337,
#  'soutendjik': 338,
#  'rationalization': 339,
#  'cantaloupe': 340,
#  'zanuck': 341,
#  'costumer': 342,
#  'postscript': 343,
#  'joker': 344,
#  'forythe': 345,
#  'emery': 346,
#  'sienna': 347,
#  'erratic': 348,
#  'wonderfalls': 349,
#  'pippin': 350,
#  'interpret': 351,
#  'kilts': 352,
#  'ronni': 353,
#  'grat': 354,
#  'hockey': 355,
#  'socket': 356,
#  'icg': 357,
#  'tone': 358,
#  'trivialized': 359,
#  'whites': 360,
#  'unflinchingly': 361,
#  'jeffs': 362,
#  'smurfs': 363,
#  'surrenders': 364,
#  'meshed': 365,
#  'stunners': 366,
#  'exterior': 367,
#  'zeppo': 368,
#  'contradictive': 369,
#  'bakshi': 370,
#  'outerbridge': 371,
#  'pandas': 372,
#  'unthinking': 373,
#  'hip': 374,
#  'fraternization': 375,
#  'sight': 376,
#  'commitophobe': 377,
#  'stammers': 378,
#  'truthful': 379,
#  'demeanor': 380,
#  'jacobs': 381,
#  'history': 382,
#  'kaylene': 383,
#  'sr': 384,
#  'globalization': 385,
#  'lags': 386,
#  'zarabeth': 387,
#  'habitants': 388,
#  'grouch': 389,
#  'predestined': 390,
#  'colcord': 391,
#  'huzoor': 392,
#  'unworkable': 393,
#  'prinz': 394,
#  'kibbutznikim': 395,
#  'gloom': 396,
#  'yawnfest': 397,
#  'fraud': 398,
#  'tugs': 399,
#  'disheartened': 400,
#  'uncanny': 401,
#  'lah': 402,
#  'overtones': 403,
#  'psychobilly': 404,
#  'nuremburg': 405,
#  'reveling': 406,
#  'boning': 407,
#  'clausen': 408,
#  'uncles': 409,
#  'plumbers': 410,
#  'wins': 411,
#  'bizarreness': 412,
#  'visualsconsidering': 413,
#  'unrestrained': 414,
#  'kasdan': 415,
#  'heterosexuality': 416,
#  'chrstmas': 417,
#  'aurora': 418,
#  'rajnikant': 419,
#  'lice': 420,
#  'asthmatic': 421,
#  'mcclurg': 422,
#  'wackyest': 423,
#  'sigrid': 424,
#  'serving': 425,
#  'connery': 426,
#  'subliminally': 427,
#  'koo': 428,
#  'spiritualism': 429,
#  'zhu': 430,
#  'boyhood': 431,
#  'excavated': 432,
#  'valentinov': 433,
#  'record': 434,
#  'upped': 435,
#  'alters': 436,
#  'knight': 437,
#  'tattersall': 438,
#  'waster': 439,
#  'swords': 440,
#  'moebius': 441,
#  'synonym': 442,
#  'misportrayed': 443,
#  'proportionality': 444,
#  'pointsthe': 445,
#  'chokes': 446,
#  'shylock': 447,
#  'idiocracy': 448,
#  'trapero': 449,
#  'supposedly': 450,
#  'amidst': 451,
#  'lottie': 452,
#  'internet': 453,
#  'unspools': 454,
#  'epigrams': 455,
#  'such': 456,
#  'engineered': 457,
#  'berryman': 458,
#  'gujarati': 459,
#  'spots': 460,
#  'implication': 461,
#  'scotched': 462,
#  'veil': 463,
#  'ungraspable': 464,
#  'yeoh': 465,
#  'amg': 466,
#  'boatthus': 467,
#  'troublesome': 468,
#  'dexadrine': 469,
#  'breadbasket': 470,
#  'bishop': 471,
#  'buttafuoco': 472,
#  'perspiration': 473,
#  'lilia': 474,
#  'realms': 475,
#  'humankind': 476,
#  'brilliantly': 477,
#  'delenn': 478,
#  'directionless': 479,
#  'brigante': 480,
#  'remedios': 481,
#  'michiko': 482,
#  'snickered': 483,
#  'hungarian': 484,
#  'abortive': 485,
#  'bibbity': 486,
#  'situationally': 487,
#  'gittes': 488,
#  'drssing': 489,
#  'construction': 490,
#  'stotz': 491,
#  'auditory': 492,
#  'harlan': 493,
#  'tombs': 494,
#  'retsuden': 495,
#  'clicking': 496,
#  'inexpensive': 497,
#  'yootha': 498,
#  'stupidness': 499,
#  'millionare': 500,
#  'tent': 501,
#  'stash': 502,
#  'matchpoint': 503,
#  'receptacle': 504,
#  'footsteps': 505,
#  'tamed': 506,
#  'yashpal': 507,
#  'pohler': 508,
#  'mccaughan': 509,
#  'sepoys': 510,
#  'kerby': 511,
#  'recombining': 512,
#  'lie': 513,
#  'independant': 514,
#  'shaun': 515,
#  'thenali': 516,
#  'thinning': 517,
#  'christie': 518,
#  'prophesies': 519,
#  'looooooooong': 520,
#  'lonesome': 521,
#  'outwitted': 522,
#  'overshadowed': 523,
#  'noces': 524,
#  'geller': 525,
#  'franco': 526,
#  'ambersoms': 527,
#  'mousy': 528,
#  'xica': 529,
#  'keeling': 530,
#  'rooftop': 531,
#  'skala': 532,
#  'turmoils': 533,
#  'teenaged': 534,
#  'invokes': 535,
#  'troi': 536,
#  'ignites': 537,
#  'csikos': 538,
#  'deceased': 539,
#  'gum': 540,
#  'bleeping': 541,
#  'aladdin': 542,
#  'plissken': 543,
#  'funking': 544,
#  'perfumes': 545,
#  'bushell': 546,
#  'stupifying': 547,
#  'sonali': 548,
#  'mounting': 549,
#  'allows': 550,
#  'mouthings': 551,
#  'robberies': 552,
#  'philippine': 553,
#  'gramm': 554,
#  'custer': 555,
#  'bodega': 556,
#  'froth': 557,
#  'waaaaaay': 558,
#  'ballgame': 559,
#  'sodomy': 560,
#  'provocative': 561,
#  'discouraging': 562,
#  'spence': 563,
#  'lateral': 564,
#  'umpteenth': 565,
#  'forever': 566,
#  'unqiue': 567,
#  'fsb': 568,
#  'indefinitely': 569,
#  'untenable': 570,
#  'yip': 571,
#  'entirety': 572,
#  'shetan': 573,
#  'forysthe': 574,
#  'despondent': 575,
#  'presentations': 576,
#  'brim': 577,
#  'dins': 578,
#  'humanism': 579,
#  'plump': 580,
#  'sincerely': 581,
#  'la': 582,
#  'jarred': 583,
#  'norwegians': 584,
#  'instigator': 585,
#  'lobster': 586,
#  'bilson': 587,
#  'nor': 588,
#  'impulses': 589,
#  'newmail': 590,
#  'beefs': 591,
#  'excursions': 592,
#  'insightfulness': 593,
#  'citroen': 594,
#  'conjectural': 595,
#  'beheads': 596,
#  'skewered': 597,
#  'nat': 598,
#  'reprinted': 599,
#  'shaves': 600,
#  'loathes': 601,
#  'syncing': 602,
#  'anarchist': 603,
#  'jook': 604,
#  'halve': 605,
#  'steiger': 606,
#  'vertes': 607,
#  'carribien': 608,
#  'ryus': 609,
#  'paneled': 610,
#  'ion': 611,
#  'wirsching': 612,
#  'km': 613,
#  'pasty': 614,
#  'alongwith': 615,
#  'substantiates': 616,
#  'wondered': 617,
#  'groucho': 618,
#  'suwkowa': 619,
#  'imprimatur': 620,
#  'greenhouse': 621,
#  'sloppiness': 622,
#  'langenkamp': 623,
#  'vining': 624,
#  'visiteurs': 625,
#  'orlac': 626,
#  'idia': 627,
#  'daymio': 628,
#  'kostic': 629,
#  'outward': 630,
#  'mosley': 631,
#  'winemaker': 632,
#  'mcneely': 633,
#  'kangwon': 634,
#  'sariana': 635,
#  'pixardreamworks': 636,
#  'candid': 637,
#  'anyones': 638,
#  'categorise': 639,
#  'dunnno': 640,
#  'foudre': 641,
#  'tito': 642,
#  'chopin': 643,
#  'hairstyles': 644,
#  'fleeting': 645,
#  'walrus': 646,
#  'orenthal': 647,
#  'fukuky': 648,
#  'wreaking': 649,
#  'ecxellent': 650,
#  'wonderfully': 651,
#  'shitfaced': 652,
#  'eventuates': 653,
#  'tweezers': 654,
#  'upstairs': 655,
#  'maxwells': 656,
#  'ihop': 657,
#  'attaches': 658,
#  'binder': 659,
#  'athey': 660,
#  'afb': 661,
#  'grading': 662,
#  'whoppie': 663,
#  'trashing': 664,
#  'outnumbered': 665,
#  'silicone': 666,
#  'bookended': 667,
#  'mochanian': 668,
#  'coca': 669,
#  'oooooh': 670,
#  'trader': 671,
#  'authenticating': 672,
#  'realisticly': 673,
#  'exiled': 674,
#  'stephan': 675,
#  'wonky': 676,
#  'boppers': 677,
#  'cromoscope': 678,
#  'daytiem': 679,
#  'cape': 680,
#  'vincenzoni': 681,
#  'natal': 682,
#  'angus': 683,
#  'solemnly': 684,
#  'flunky': 685,
#  'discredited': 686,
#  'lunches': 687,
#  'expressionless': 688,
#  'suffolk': 689,
#  'avenged': 690,
#  'braces': 691,
#  'pikachu': 692,
#  'constituted': 693,
#  'compromise': 694,
#  'handycam': 695,
#  'saltcoats': 696,
#  'wiggly': 697,
#  'characters': 698,
#  'despising': 699,
#  'spotless': 700,
#  'throngs': 701,
#  'neared': 702,
#  'shamefull': 703,
#  'recreate': 704,
#  'elegance': 705,
#  'solving': 706,
#  'popoff': 707,
#  'trekovsky': 708,
#  'shriek': 709,
#  'austrailia': 710,
#  'pussies': 711,
#  'hitching': 712,
#  'raw': 713,
#  'scientalogy': 714,
#  'congruity': 715,
#  'rattlesnakes': 716,
#  'thirlby': 717,
#  'doen': 718,
#  'thick': 719,
#  'drill': 720,
#  'compromised': 721,
#  'corners': 722,
#  'turncoats': 723,
#  'poorly': 724,
#  'pemberton': 725,
#  'regretful': 726,
#  'evangelist': 727,
#  'odds': 728,
#  'infrequent': 729,
#  'spoilerand': 730,
#  'merideth': 731,
#  'qissi': 732,
#  'dissing': 733,
#  'hinglish': 734,
#  'jean': 735,
#  'evading': 736,
#  'courted': 737,
#  'vignettes': 738,
#  'shakers': 739,
#  'vrits': 740,
#  'wearers': 741,
#  'tempo': 742,
#  'cohen': 743,
#  'abhays': 744,
#  'coffie': 745,
#  'decrying': 746,
#  'hegemony': 747,
#  'documentalists': 748,
#  'basket': 749,
#  'steamroller': 750,
#  'tractacus': 751,
#  'doted': 752,
#  'footman': 753,
#  'personify': 754,
#  'groden': 755,
#  'erics': 756,
#  'founds': 757,
#  'balloons': 758,
#  'cancan': 759,
#  'electricians': 760,
#  'haugland': 761,
#  'chastise': 762,
#  'bacall': 763,
#  'velocity': 764,
#  'quietest': 765,
#  'outshines': 766,
#  'embarassment': 767,
#  'sloshing': 768,
#  'informative': 769,
#  'collaboration': 770,
#  'worldwide': 771,
#  'telephones': 772,
#  'colossus': 773,
#  'untrue': 774,
#  'luv': 775,
#  'unconnected': 776,
#  'funding': 777,
#  'slotted': 778,
#  'necked': 779,
#  'dunston': 780,
#  'intl': 781,
#  'kedrova': 782,
#  'shortness': 783,
#  'delegate': 784,
#  'renoue': 785,
#  'enter': 786,
#  'anne': 787,
#  'culver': 788,
#  'kidman': 789,
#  'astrogators': 790,
#  'ensnaring': 791,
#  'civl': 792,
#  'complementing': 793,
#  'memento': 794,
#  'roberti': 795,
#  'gangmembers': 796,
#  'premature': 797,
#  'gurus': 798,
#  'mcveigh': 799,
#  'ashwood': 800,
#  'stales': 801,
#  'pinocchio': 802,
#  'adoption': 803,
#  'mirthless': 804,
#  'feasts': 805,
#  'exploitational': 806,
#  'expectant': 807,
#  'manif': 808,
#  'philosophical': 809,
#  'routine': 810,
#  'synonymous': 811,
#  'chasey': 812,
#  'wove': 813,
#  'crucial': 814,
#  'evolutionists': 815,
#  'dangerman': 816,
#  'palest': 817,
#  'fungal': 818,
#  'intoxication': 819,
#  'ah': 820,
#  'injures': 821,
#  'discerning': 822,
#  'testa': 823,
#  'congenial': 824,
#  'dixon': 825,
#  'vastly': 826,
#  'geologist': 827,
#  'snl': 828,
#  'bismillahhirrahmannirrahim': 829,
#  'igniting': 830,
#  'eclecticism': 831,
#  'submerging': 832,
#  'imbalance': 833,
#  'circumvented': 834,
#  'ranko': 835,
#  'softy': 836,
#  'aloud': 837,
#  'kinji': 838,
#  'adhd': 839,
#  'hom': 840,
#  'raises': 841,
#  'parkes': 842,
#  'facial': 843,
#  'peers': 844,
#  'misogyny': 845,
#  'cuppa': 846,
#  'bodices': 847,
#  'under': 848,
#  'compelled': 849,
#  'dancin': 850,
#  'acted': 851,
#  'collide': 852,
#  'clarissa': 853,
#  'codename': 854,
#  'wrongfully': 855,
#  'bufoonery': 856,
#  'timon': 857,
#  'dwindle': 858,
#  'grieco': 859,
#  'abdul': 860,
#  'frequents': 861,
#  'zed': 862,
#  'chaleuruex': 863,
#  'hobby': 864,
#  'soberly': 865,
#  'lensman': 866,
#  'morrow': 867,
#  'foreboding': 868,
#  'bergen': 869,
#  'upbeat': 870,
#  'notld': 871,
#  'westlake': 872,
#  'enunciation': 873,
#  'fragata': 874,
#  'misinterpreting': 875,
#  'sodomized': 876,
#  'picard': 877,
#  'ackland': 878,
#  'whitechapel': 879,
#  'devereux': 880,
#  'scarynot': 881,
#  'lassie': 882,
#  'swansong': 883,
#  'mammals': 884,
#  'dupree': 885,
#  'failures': 886,
#  'dumbfoundingly': 887,
#  'prostitution': 888,
#  'cork': 889,
#  'surnames': 890,
#  'osiris': 891,
#  'bounce': 892,
#  'stupidly': 893,
#  'sciorra': 894,
#  'shrink': 895,
#  'government': 896,
#  'columnist': 897,
#  'brendan': 898,
#  'basement': 899,
#  'stabbed': 900,
#  'engrossed': 901,
#  'sirhan': 902,
#  'mcbain': 903,
#  'loll': 904,
#  'nellie': 905,
#  'spetznatz': 906,
#  'michener': 907,
#  'cheese': 908,
#  'seduces': 909,
#  'convict': 910,
#  'ff': 911,
#  'punctuate': 912,
#  'raptor': 913,
#  'looters': 914,
#  'being': 915,
#  'kindle': 916,
#  'lorenzo': 917,
#  'stripclub': 918,
#  'neuroinfectious': 919,
#  'suburb': 920,
#  'pacierkowski': 921,
#  'sunburst': 922,
#  'golmaal': 923,
#  'holographic': 924,
#  'bandmates': 925,
#  'deify': 926,
#  'mope': 927,
#  'jannetty': 928,
#  'deaththreats': 929,
#  'shabbily': 930,
#  'immersive': 931,
#  'helloooo': 932,
#  'submission': 933,
#  'comparison': 934,
#  'wannabee': 935,
#  'eburne': 936,
#  'frights': 937,
#  'mentoring': 938,
#  'beatings': 939,
#  'horgan': 940,
#  'motta': 941,
#  'vitti': 942,
#  'revolucion': 943,
#  'planner': 944,
#  'lacklustre': 945,
#  'bakvaas': 946,
#  'schaeffer': 947,
#  'sorcerers': 948,
#  'tanaka': 949,
#  'adelade': 950,
#  'naggy': 951,
#  'fg': 952,
#  'jell': 953,
#  'cheng': 954,
#  'slate': 955,
#  'earning': 956,
#  'nerae': 957,
#  'stairwells': 958,
#  'detects': 959,
#  'luis': 960,
#  'schilling': 961,
#  'transplant': 962,
#  'osric': 963,
#  'tainting': 964,
#  'pathos': 965,
#  'illusions': 966,
#  'ringo': 967,
#  'categorize': 968,
#  'abraham': 969,
#  'designate': 970,
#  'stephen': 971,
#  'harvet': 972,
#  'super': 973,
#  'swaggering': 974,
#  'broadly': 975,
#  'bismarck': 976,
#  'tactics': 977,
#  'firgens': 978,
#  'lauderdale': 979,
#  'foreclosure': 980,
#  'astronomically': 981,
#  'uppermost': 982,
#  'serbo': 983,
#  'succeeds': 984,
#  'darkseid': 985,
#  'handbook': 986,
#  'supporter': 987,
#  'inquires': 988,
#  'disposal': 989,
#  'ele': 990,
#  'jorg': 991,
#  'heretical': 992,
#  'louts': 993,
#  'fallafel': 994,
#  'starnberg': 995,
#  'henderson': 996,
#  'mujhse': 997,
#  'mcgann': 998,
#  'anticlimatic': 999,
#  ...}

# %%
def update_input_layer(review):
  global layer_0
  layer_0 *= 0
  for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[18.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
def get_target_for_label(label):
  if(label == 'POSITIVE'):
    return 1
  else:
    return 0

# %%
import sys
import numpy as np
import time

# %%
class SentimentNetwork:
  def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
    np.random.seed(1)
    self.pre_process_data(reviews, labels)
    self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

  def pre_process_data(self, reviews, labels):
    review_vocab = set()
    for review in reviews:
      for word in review.split(" "):
        review_vocab.add(word)

    self.review_vocab = list(review_vocab)

    label_vocab = set()
    for label in labels:
      label_vocab.add(label)

    self.label_vocab = list(label_vocab)

    self.review_vocab_size = len(self.review_vocab)
    self.label_vocab_size = len(self.label_vocab)

    self.word2index = {}
    for i, word in enumerate(self.review_vocab):
      self.word2index[word] = i

    self.label2index = {}
    for i, label in enumerate(self.label_vocab):
      self.label2index[label] = i

  def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):

    self.input_nodes = input_nodes
    self.hidden_nodes = hidden_nodes
    self.output_nodes = output_nodes

    self.learning_rate = learning_rate

    self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
    self.layer_0 = np.zeros((1,input_nodes))

  def update_input_layer(self,review):
    self.layer_0 *= 0
    for word in review.split(" "):
      if(word in self.word2index.keys()):
          self.layer_0[0][self.word2index[word]] = 1

  def get_target_for_label(self,label):
    if(label == 'POSITIVE'):
      return 1
    else:
      return 0

  def sigmoid(self,x):
    return 1 / (1 + np.exp(-x))
  
  def sigmoid_output_2_derivative(self,output):
    return output * (1 - output)


  def train(self, training_reviews, training_labels):
    assert(len(training_reviews) == len(training_labels))
    correct_so_far = 0
    start = time.time()

    for i in range(len(training_reviews)):
      review = training_reviews[i]
      label = training_labels[i]
      self.update_input_layer(review)
      layer_1 = self.layer_0.dot(self.weights_0_1)
      layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
      layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
      layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)


      layer_1_error = layer_2_delta.dot(self.weights_1_2.T)
      layer_1_delta = layer_1_error
      self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate
      self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate 


      if(layer_2 >= 0.5 and label == 'POSITIVE'):
        correct_so_far += 1
      elif(layer_2 < 0.5 and label == 'NEGATIVE'):
        correct_so_far += 1

      elapsed_time = float(time.time() - start)
      reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0

      sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
      
      if(i % 2500 == 0):
                print("")

  def test(self, testing_reviews, testing_labels):

    correct = 0
    start = time.time()
    for i in range(len(testing_reviews)):
      pred = self.run(testing_reviews[i])
      if(pred == testing_labels[i]):
        correct += 1

    elapsed_time = float(time.time() - start)
    reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
    sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                      + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                      + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                      + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    

  def run(self, review):
    self.update_input_layer(review.lower())
    layer_1 = self.layer_0.dot(self.weights_0_1)
    layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
    if(layer_2[0] >= 0.5):
        return "POSITIVE"
    else:
        return "NEGATIVE"

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):668.3 #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):236.6 #Correct:1251 #Trained:2501 Training Accuracy:50.0%
# Progress:20.8% Speed(reviews/sec):226.0 #Correct:2501 #Trained:5001 Training Accuracy:50.0%
# Progress:31.2% Speed(reviews/sec):222.0 #Correct:3751 #Trained:7501 Training Accuracy:50.0%
# Progress:41.6% Speed(reviews/sec):224.5 #Correct:5001 #Trained:10001 Training Accuracy:50.0%
# Progress:52.0% Speed(reviews/sec):223.9 #Correct:6251 #Trained:12501 Training Accuracy:50.0%
# Progress:62.5% Speed(reviews/sec):223.8 #Correct:7501 #Trained:15001 Training Accuracy:50.0%
# Progress:72.9% Speed(reviews/sec):224.1 #Correct:8751 #Trained:17501 Training Accuracy:50.0%
# Progress:83.3% Speed(reviews/sec):225.0 #Correct:10001 #Trained:20001 Training Accuracy:50.0%
# Progress:93.7% Speed(reviews/sec):225.2 #Correct:11251 #Trained:22501 Training Accuracy:50.0%
# Progress:99.9% Speed(reviews/sec):224.6 #Correct:12000 #Trained:24000 Training Accuracy:50.0%

# %%
mlp = SentimentNetwork(reviews[:-2000],labels[:-2000], learning_rate=0.001)
mlp.train(reviews[:-2000],labels[:-2000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.8% Speed(reviews/sec):203.1 #Correct:1259 #Trained:2501 Training Accuracy:50.3%
# Progress:21.7% Speed(reviews/sec):200.0 #Correct:2631 #Trained:5001 Training Accuracy:52.6%
# Progress:32.6% Speed(reviews/sec):201.2 #Correct:4066 #Trained:7501 Training Accuracy:54.2%
# Progress:43.4% Speed(reviews/sec):201.9 #Correct:5576 #Trained:10001 Training Accuracy:55.7%
# Progress:54.3% Speed(reviews/sec):201.5 #Correct:7180 #Trained:12501 Training Accuracy:57.4%
# Progress:65.2% Speed(reviews/sec):200.7 #Correct:8733 #Trained:15001 Training Accuracy:58.2%
# Progress:76.0% Speed(reviews/sec):192.0 #Correct:10343 #Trained:17501 Training Accuracy:59.0%
# Progress:86.9% Speed(reviews/sec):185.9 #Correct:12008 #Trained:20001 Training Accuracy:60.0%
# Progress:97.8% Speed(reviews/sec):185.8 #Correct:13652 #Trained:22501 Training Accuracy:60.6%
# Progress:99.9% Speed(reviews/sec):185.8 #Correct:14000 #Trained:23000 Training Accuracy:60.8%

# %%
mlp = SentimentNetwork(reviews[:-2000],labels[:-2000], learning_rate=0.001)
mlp.train(reviews[:-2000],labels[:-2000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.8% Speed(reviews/sec):185.9 #Correct:1941 #Trained:2501 Training Accuracy:77.6%
# Progress:21.7% Speed(reviews/sec):197.0 #Correct:3988 #Trained:5001 Training Accuracy:79.7%
# Progress:32.6% Speed(reviews/sec):201.9 #Correct:6086 #Trained:7501 Training Accuracy:81.1%
# Progress:43.4% Speed(reviews/sec):202.9 #Correct:8205 #Trained:10001 Training Accuracy:82.0%
# Progress:54.3% Speed(reviews/sec):204.3 #Correct:10338 #Trained:12501 Training Accuracy:82.6%
# Progress:65.2% Speed(reviews/sec):204.8 #Correct:12424 #Trained:15001 Training Accuracy:82.8%
# Progress:76.0% Speed(reviews/sec):205.5 #Correct:14525 #Trained:17501 Training Accuracy:82.9%
# Progress:86.9% Speed(reviews/sec):205.8 #Correct:16698 #Trained:20001 Training Accuracy:83.4%
# Progress:97.8% Speed(reviews/sec):206.7 #Correct:18857 #Trained:22501 Training Accuracy:83.8%
# Progress:99.9% Speed(reviews/sec):206.9 #Correct:19279 #Trained:23000 Training Accuracy:83.8%

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):784.5 #Correct:840 #Tested:1000 Testing Accuracy:84.0%
